# %%
from dash import Dash, html, dcc, Input, Output
from dash.dash_table import DataTable
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://bigdata:Bigdata123!!@192.168.56.101:3306/SampleDB")
conn = engine.connect()

# %%
## 데이터 베이스 목록
db_list = pd.read_sql("select distinct table_schema from information_schema.tables",conn).loc[:,"table_schema"]
db_list = db_list.values

# %%
app = Dash(__name__)
app.layout = html.Div(
    [
        dcc.Dropdown(id="db-list-dropdown",
                    options = [{"label":i,"value":i} for i in db_list]),
        html.Div(id="table-dropdown"),
        html.Div(id="column-checklist"),
        html.Div(id="sql-stmt"),
        html.Div(id="table-contents"),
    ]
)

# %%
@app.callback(
    Output("table-dropdown","children"),
    Input("db-list-dropdown","value")
)
def update_table_dropdown_list(dbname):
    table_list = pd.read_sql(f"select table_name from information_schema.tables where table_schema = '{dbname}'",conn)
    table_list = table_list.loc[:,"table_name"].values
    table_list = [{"label":i,"value":i} for i in table_list]
    return html.Div(
        [
            dcc.Dropdown(id = "table-list-dropdown",
                         options = table_list)
        ]
    )

@app.callback(
    Output("column-checklist","children"),
    Input("db-list-dropdown","value"),
    Input("table-list-dropdown","value"),
)
def update_column_list(dbname,tablename):
    column_list = pd.read_sql(f"select column_name from information_schema.columns where table_schema = '{dbname}' and table_name = '{tablename}'",conn)
    column_list = column_list.loc[:,"column_name"]
    column_list = column_list.values
    return html.Div([
        dcc.Checklist(
            id = "column-list",
            options = column_list,
            value = column_list[[0]]
        )
    ])


@app.callback(
    Output("sql-stmt","children"),
    Input("db-list-dropdown","value"),
    Input("table-list-dropdown","value"),
    Input("column-list","value"),
)

def update_sql_stmt(dbname, tablename, columnname):
    columnname = ','.join(columnname)
    stmt = f"select {columnname} from {dbname}.{tablename}"
    return html.Div([html.H2(stmt)])


@app.callback(
    Output("table-contents","children"),
    Input("db-list-dropdown","value"),
    Input("table-list-dropdown","value"),
)
def update_table_contents(dbname,tablename):
    table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
    return html.Div(
        [
            DataTable(
                 table_contents.to_dict('records'), 
                 [{"name": i, "id": i} for i in table_contents.columns]
            )
        ]
    )

# %%
','.join(['번호'])
# Out:
# '번호'

# %%
app.run_server(host="192.168.56.101",port=5555)
# Out:
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
# Dash is running on http://192.168.56.101:5555/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.56.101:5555/ (Press CTRL+C to quit)
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "GET / HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 29, in update_column_list
#     value = column_list[[0]]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 192.168.56.1 - - [22/Feb/2022 10:45:35] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'None.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'None.None' doesn't exist")
# [SQL: select * from None.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'None.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'None.None' doesn't exist")
# [SQL: select * from None.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'None.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'None.None' doesn't exist")
# [SQL: select * from None.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'None.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'None.None' doesn't exist")
# [SQL: select * from None.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# ...
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'SampleDB.None' doesn't exist")
# [SQL: select * from SampleDB.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'SampleDB.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'SampleDB.None' doesn't exist")
# [SQL: select * from SampleDB.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.ProgrammingError: (1146, "Table 'SampleDB.None' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1344, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "/tmp/ipykernel_1754/4257497786.py", line 52, in update_table_contents
#     table_contents = pd.read_sql(f"select * from {dbname}.{tablename}",conn)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 628, in read_sql
#     return pandas_sql.read_query(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1579, in read_query
#     result = self.execute(*args)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py", line 1424, in execute
#     return self.connectable.execution_options().execute(*args, **kwargs)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1248, in execute
#     return self._exec_driver_sql(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1547, in _exec_driver_sql
#     ret = self._execute_context(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1814, in _execute_context
#     self._handle_dbapi_exception(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1995, in _handle_dbapi_exception
#     util.raise_(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1771, in _execute_context
#     self.dialect.do_execute(
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 717, in do_execute
#     cursor.execute(statement, parameters)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/kwlee/anaconda3/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'SampleDB.None' doesn't exist")
# [SQL: select * from SampleDB.None]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# 192.168.56.1 - - [22/Feb/2022 10:45:37] "POST /_dash-update-component HTTP/1.1" 500 -
# 192.168.56.1 - - [22/Feb/2022 10:45:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:39] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:39] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 10:45:47] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = Dash(__name__)
app.layout = html.Div(
    [
       DataTable(df.to_dict('records'), 
                 [{"name": i, "id": i} for i in df.columns],
                  editable=True,
                  filter_action="native",
                  sort_action="native",
                  sort_mode="multi",
                  row_selectable="multi",
                  row_deletable=False,
                  selected_rows=[],
                  page_action="native",
                  page_current= 0,
                  page_size= 6,
            # page_action='none',
            # style_cell={
            # 'whiteSpace': 'normal'
            # },
            # fixed_rows={ 'headers': True, 'data': 0 },
            # virtualization=False,
            style_cell_conditional=[
                {'if': {'column_id': 'countriesAndTerritories'},
                 'width': '40%', 'textAlign': 'left'},
                {'if': {'column_id': 'deaths'},
                 'width': '30%', 'textAlign': 'left'},
                {'if': {'column_id': 'cases'},
                 'width': '30%', 'textAlign': 'left'},
            ])    
    ]

)

app.run_server(host="192.168.56.101",port=7777)
# Out:
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
# Dash is running on http://192.168.56.101:7777/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.56.101:7777/ (Press CTRL+C to quit)
# 192.168.56.1 - - [22/Feb/2022 09:24:45] "GET / HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 09:24:45] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 09:24:45] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 09:24:45] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 200 -
# 192.168.56.1 - - [22/Feb/2022 09:24:45] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 200 -
